# %%
# this is a list of features which are used in the Community Commitment Score
features = [
    'How well security testing is done for an open-source project',
    'How well vulnerabilities are patched',
    'How fast vulnerabilities are patched',
    'How well open-source community is aware about security',
    'Open-source project activity score',
    'Open-source project popularity score',
    'How well open-source community commits to support an open-source project'
]

# %%
import commons


# load test vectors
file = '../../../../../src/main/resources/com/sap/oss/phosphor/fosstars/model/score/oss/OssSecurityScoreTestVectors.yml'
test_vectors = commons.load_test_vectors_from_yaml(file, features)

# print out the test vectors
test_vectors
# Out:
#            alias  \
# 0  test_vector_0
# 1  test_vector_1
# 2  test_vector_2
# 3  test_vector_3
# 4  test_vector_4
# 5  test_vector_5
# 6  test_vector_6
# 7  test_vector_7
# 8  test_vector_8
# 9  test_vector_9
#
#    How well security testing is done for an open-source project  \
# 0                                                0.0
# 1                                                0.0
# 2                                                5.0
# 3                                                0.0
# 4                                                0.0
# 5                                                8.0
# 6                                               10.0
# 7                                                0.0
# 8                                               10.0
# 9                                               10.0
#
#    Open-source project popularity score  \
# 0                                   0.0
# 1                                   5.0
# 2                                   5.0
# 3                                  10.0
# 4                                   5.0
# 5                                   5.0
# 6                                   5.0
# 7                                   7.0
# 8                                   7.0
# 9                                  10.0
#
#    How well open-source community commits to support an open-source project  \
# 0                                                0.0
# 1                                                5.0
# 2                                                5.0
# 3                                               10.0
# 4                                                5.0
# 5                                                5.0
# 6                                                5.0
# 7                                                7.0
# 8                                                7.0
# 9                                               10.0
#
#    How well vulnerabilities are patched  \
# 0                                   0.0
# 1                                   0.0
# 2                                   5.0
# 3                                   0.0
# 4                                  10.0
# 5                                   8.0
# 6                                  10.0
# 7                                  10.0
# 8                                  10.0
# 9                                  10.0
#
#    How well open-source community is aware about security  \
# 0                                                0.0
# 1                                                0.0
# 2                                                5.0
# 3                                                0.0
# 4                                                0.0
# 5                                                8.0
# 6                                               10.0
# 7                                                0.0
# 8                                               10.0
# 9                                               10.0
#
#    Open-source project activity score  How fast vulnerabilities are patched  \
# 0                                 0.0                                   0.0
# 1                                 5.0                                   0.0
# 2                                 5.0                                   5.0
# 3                                10.0                                   0.0
# 4                                 5.0                                   5.0
# 5                                 5.0                                   8.0
# 6                                 5.0                                  10.0
# 7                                 7.0                                  10.0
# 8                                 7.0                                  10.0
# 9                                10.0                                  10.0
#
#    score_from  score_to
# 0         0.0       0.5
# 1         1.0       2.0
# 2         3.0       5.0
# 3         2.0       4.0
# 4         4.0       5.0
# 5         6.0       8.0
# 6         7.0       8.0
# 7         5.0       6.0
# 8         8.0       9.0
# 9         9.9      10.0

# %%
commons.draw_hists(features, test_vectors)
