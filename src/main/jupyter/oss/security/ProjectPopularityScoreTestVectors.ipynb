# %%
# this is a list of features which are used in the Project Popularity Score
features = [
    'Number of stars for a GitHub repository',
    'Number of watchers for a GitHub repository'
]

# %%
import commons


# load test vectors
file = '../../../../../src/main/resources/com/sap/oss/phosphor/fosstars/model/score/oss/ProjectPopularityScoreTestVectors.yml'
test_vectors = commons.load_test_vectors_from_yaml(file, features)

# print out the test vectors
test_vectors
# Out:
#              alias Number of stars for a GitHub repository  \
# 0    test_vector_0                                 unknown
# 1    test_vector_1                                       0
# 2    test_vector_2                                      10
# 3    test_vector_3                                     100
# 4    test_vector_4                                    1000
# 5    test_vector_5                                      10
# 6    test_vector_6                                     100
# 7    test_vector_7                                    1000
# 8    test_vector_8                                    5000
# 9    test_vector_9                                   10000
# 10  test_vector_10                                   20000
#
#    Number of watchers for a GitHub repository  score_from  score_to
# 0                                     unknown         0.0       0.1
# 1                                           0         0.0       0.5
# 2                                           0         0.0       1.0
# 3                                           0         0.0       2.0
# 4                                           0         1.0       2.0
# 5                                           2         0.0       1.0
# 6                                          10         0.0       2.0
# 7                                          20         1.0       2.0
# 8                                          20         4.0       6.0
# 9                                         100         8.0      10.0
# 10                                        300         9.0      10.0

# %%
commons.draw_hists(features, test_vectors)
