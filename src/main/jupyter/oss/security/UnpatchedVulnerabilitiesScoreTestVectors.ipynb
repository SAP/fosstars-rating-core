# %%
# this is a list of features which are used in the Unpatched Vulnerability Score
features = [
    'Info about vulnerabilities in open-source project'
]

# %%
import commons


# load test vectors
file = '../../../../../src/main/resources/com/sap/sgs/phosphor/fosstars/model/score/oss/UnpatchedVulnerabilitiesScoreTestVectors.yml'
test_vectors = commons.load_test_vectors_from_yaml(file, features)

# print out the test vectors
test_vectors
# Out:
#            alias Info about vulnerabilities in open-source project  \
# 0  test_vector_0                                           unknown
# 1  test_vector_1                                               NaN
# 2  test_vector_2                                               NaN
# 3  test_vector_3                                               NaN
# 4  test_vector_4                                               NaN
# 5  test_vector_5                                               NaN
# 6  test_vector_6                                               NaN
# 7  test_vector_7                                               NaN
# 8  test_vector_8                                               NaN
#
#    score_from  score_to
# 0         0.0       1.0
# 1         8.0      10.0
# 2         9.0      10.0
# 3         7.0       9.0
# 4         6.0       8.0
# 5         1.0       3.0
# 6         5.0       8.0
# 7         1.0       3.0
# 8         0.0       1.0
